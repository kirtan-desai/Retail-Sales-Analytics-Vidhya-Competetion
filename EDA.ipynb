# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("bmtrain.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
len(df['Outlet_Location_Type'])
# Out:
# 8523

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df['Outlet_Location_Type'].replace({'Tier 1':1,'Tier 2':2,'Tier 3':3},inplace=True)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                       1999      Medium                     1
# 1                       2009      Medium                     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 799.2+ KB

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content'].replace(['Low Fat','LF','low fat'],1,inplace=True)
df['Item_Fat_Content'].replace(['Regular','reg'],2,inplace=True)
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                       1999      Medium                     1
# 1                       2009      Medium                     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   int64
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 799.2+ KB

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
from datetime import date
current_year = date.today().year

# %%
df['Outlet_Establishment_Year'] = current_year - df['Outlet_Establishment_Year'] 
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                         21      Medium                     1
# 1                         11      Medium                     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   int64
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 799.2+ KB

# %%
df["Outlet_Type"].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Outlet_Type'])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                         21      Medium                     1
# 1                         11      Medium                     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    7060 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    6113 non-null   object
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
sns.barplot(x=df['Outlet_Size'],y=df['Item_Outlet_Sales'])

# %%
df['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
df1 = df[pd.isna(df['Outlet_Size'])]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2410 entries, 3 to 8519
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                2410 non-null   object
#  1   Item_Weight                    2410 non-null   float64
#  2   Item_Fat_Content               2410 non-null   int64
#  3   Item_Visibility                2410 non-null   float64
#  4   Item_Type                      2410 non-null   object
#  5   Item_MRP                       2410 non-null   float64
#  6   Outlet_Identifier              2410 non-null   object
#  7   Outlet_Establishment_Year      2410 non-null   int64
#  8   Outlet_Size                    0 non-null      object
#  9   Outlet_Location_Type           2410 non-null   int64
#  10  Item_Outlet_Sales              2410 non-null   float64
#  11  Outlet_Type_Grocery Store      2410 non-null   uint8
# ...

# %%
df1['Outlet_Identifier'].value_counts()
# Out:
# OUT045    929
# OUT017    926
# OUT010    555
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df.groupby('Outlet_Size').Outlet_Identifier.value_counts()
# Out:
# Outlet_Size  Outlet_Identifier
# High         OUT013               932
# Medium       OUT027               935
#              OUT049               930
#              OUT018               928
# Small        OUT035               930
#              OUT046               930
#              OUT019               528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# After observation, the outlet size does not seem to depend on outlet location type and outlet type. Hence filling the missing values with random data

# %%
df.loc[df.Outlet_Identifier=='OUT010', ['Outlet_Size']] = 'Medium'
df.loc[df.Outlet_Identifier=='OUT017', ['Outlet_Size']] = 'High'
df.loc[df.Outlet_Identifier=='OUT045', ['Outlet_Size']] = 'High'

# %%
sns.barplot(x=df['Outlet_Size'],y=df['Item_Outlet_Sales'])

# %% [markdown]
# This was the only possible combination of assigning missing values to three stores which had missing values without bringing big alterations to the bar graph

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    7060 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   object
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df['Item_Identifier'].value_counts().count()
# Out:
# 1559

# %%
df1 = df[pd.isna(df['Item_Weight'])]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 7 to 8504
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                1463 non-null   object
#  1   Item_Weight                    0 non-null      float64
#  2   Item_Fat_Content               1463 non-null   int64
#  3   Item_Visibility                1463 non-null   float64
#  4   Item_Type                      1463 non-null   object
#  5   Item_MRP                       1463 non-null   float64
#  6   Outlet_Identifier              1463 non-null   object
#  7   Outlet_Establishment_Year      1463 non-null   int64
#  8   Outlet_Size                    1463 non-null   object
#  9   Outlet_Location_Type           1463 non-null   int64
#  10  Item_Outlet_Sales              1463 non-null   float64
#  11  Outlet_Type_Grocery Store      1463 non-null   uint8
# ...

# %%
len(df1['Item_Identifier'])
# Out:
# 1463

# %%
df2 = df[pd.notnull(df['Item_Weight'])]

# %%
len(df2['Item_Identifier'])
# Out:
# 7060

# %% [markdown]
# 1463 + 7062 = 8523. Hence all null values in item weight do not have any not null value in another tuple with the same identifier

# %%
df1['Item_Identifier'].value_counts().mean()
# Out:
# 1.2810858143607706

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    7060 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   object
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
plt.figure(figsize=(25,8))
sns.barplot(x=df['Item_Type'],y=df['Item_Weight'])

# %% [markdown]
# The NaN values in Item_Weight can be replaced by the mean of the column as there is no signifact relation of weight with any other factor

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   object
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                         21      Medium                     1
# 1                         11      Medium                     3
# ...

# %%
df['Outlet_Size'].replace({'Small':1,'Medium':2,'High':3},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                         21            2                     1
# 1                         11            2                     3
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                         21            2                     1
# 1                         11            2                     3
# ...

# %%
plt.figure(figsize=(20,8))
sns.barplot(x=df['Outlet_Identifier'],y=df['Item_Outlet_Sales'])

# %%
plt.figure(figsize=(5,8))
sns.barplot(x=df['Outlet_Location_Type'],y=df['Item_Outlet_Sales'])

# %%
plt.figure(figsize=(5,8))
sns.barplot(x=df['Outlet_Size'],y=df['Item_Outlet_Sales'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 35    1463
# 33     932
# 23     930
# 21     930
# 16     930
# 18     929
# 11     928
# 13     926
# 22     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df['Outlet_Establishment_Year'],y=df['Item_Outlet_Sales'])

# %%
df[df['Outlet_Establishment_Year']==22]['Outlet_Identifier'].value_counts()
# Out:
# OUT010    555
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# Hence, products sold in Outlet OUT010 have very low sale

# %%
df[df['Outlet_Establishment_Year']==35]['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# OUT027 and OUT019 were both established in the same year but OUT027 has very high sales and OUT019 has very low sales hence the year 35 shows normal sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %% [markdown]
# It can be inferred that only Outlet Type affects the sales among outlet features because of the type of products it sells

# %%
plt.figure(figsize=(23,8))
sns.barplot(x=df['Item_Type'],y=df['Item_Outlet_Sales'])

# %% [markdown]
# Item_Type doesn't seem to show any pattern on its own

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDG33    10
# FDW13    10
# FDF52     9
# FDT07     9
# DRN47     9
#          ..
# FDK57     1
# FDO33     1
# FDN52     1
# FDY43     1
# FDE52     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df.loc[df.Item_Identifier=='FDG33', ['Item_Type','Item_Outlet_Sales','Outlet_Identifier']]
# Out:
#      Item_Type  Item_Outlet_Sales Outlet_Identifier
# 231    Seafood          3435.5280            OUT027
# 1202   Seafood          2233.0932            OUT045
# 1575   Seafood           171.7764            OUT019
# 2728   Seafood           171.7764            OUT010
# 4747   Seafood          3263.7516            OUT049
# 5164   Seafood          3263.7516            OUT046
# 6112   Seafood           858.8820            OUT017
# 7011   Seafood          2061.3168            OUT018
# 7098   Seafood          2748.4224            OUT013
# 7726   Seafood          4637.9628            OUT035

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(y=df['Item_Outlet_Sales'],x=df['Item_MRP'])

# %%
df['Item_MRP'].value_counts().count()
# Out:
# 5938

# %%
plt.figure(figsize=(20,8))
sns.regplot(x="Item_MRP", y="Item_Outlet_Sales", data=df)

# %%
df[(df['Item_MRP'] > 250.0) & (df['Item_Outlet_Sales'] < 250.0)]
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 6437           FDW55         12.6                 2         0.036773
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 6437  Fruits and Vegetables  250.3092            OUT010
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 6437                         22            2                     3
#
#       Item_Outlet_Sales  Outlet_Type_Grocery Store  \
# 6437           249.0092                          1
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 6437                              0                              0
#
#       Outlet_Type_Supermarket Type3
# 6437                              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Identifier                8523 non-null   object
#  1   Item_Weight                    8523 non-null   float64
#  2   Item_Fat_Content               8523 non-null   int64
#  3   Item_Visibility                8523 non-null   float64
#  4   Item_Type                      8523 non-null   object
#  5   Item_MRP                       8523 non-null   float64
#  6   Outlet_Identifier              8523 non-null   object
#  7   Outlet_Establishment_Year      8523 non-null   int64
#  8   Outlet_Size                    8523 non-null   int64
#  9   Outlet_Location_Type           8523 non-null   int64
#  10  Item_Outlet_Sales              8523 non-null   float64
#  11  Outlet_Type_Grocery Store      8523 non-null   uint8
# ...

# %%
plt.figure(figsize=(20,8))
sns.regplot(y=df['Item_Outlet_Sales'],x=df['Item_Weight'])
